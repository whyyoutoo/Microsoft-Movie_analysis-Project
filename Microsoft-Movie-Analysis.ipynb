# %% [markdown]
# ![example](images/director_shot.jpeg)

# %% [markdown]
# # Movie Analysis
#
# **Authors:** Wesley Yu
# ***

# %% [markdown]
# ## Overview
#
# This project analyzes data from various movie databases. Descriptive analysis of the database shows how measures of central tendency in movie release dates, genres, and production budget can effect the movie's worldwide box office results. Microsoft can use this analysis to help decide which film projects to take on.

# %% [markdown]
# ## Business Problem
#
# Microsoft is making their entry into the movie buisness and wants to know what kind types of films are currently dominating the box office. Using data from movie databases, we can find patterns and trends that can help Microsoft in deciding what movie to make how how to ensure it will be successful.

# %% [markdown]
# ## Data Understanding
#
# In this project, we will be looking at datasets from two sources. The Numbers and TMDB.
# The Numbers has been tracking data about the movie industry since 1997, having the most up to date information on box office numbers and movie financials.
# TMDB is a community built and backed database on movies and TV shows. Data is constanly added and updated by a strong community that is passionate about movie and TV show data.
#
# The Numbers dataset we are working with has records from 1915 to 2020. Data on various movie's production budget, domestic, and worldwide gross box office numbers are included.
#
# TMDB dataset includes records from 1930 to 2020. Every movie has a unique TMDB ID associated to them. The dataset provides
# genre ids, popularity, and movie rating based off their community.
#
# We will be combining these two datasets to match movie financials with there respective genres of movies since 2010.

# %%
# Import standard packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import json

# %matplotlib inline

# %%
# Open numbers database and examine first 5 records
numdf = pd.read_csv('Data/tn.movie_budgets.csv.gz')
numdf.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
numdf.info() # no missing values found
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %% [markdown]
# I want to look at records from 2010 and onwards to find any patterns in more recent movies. Change <code>release_date</code> to datetime type.

# %%
# collecting records with release year of 2010 or later.
numdf['release_date'] = pd.to_datetime(numdf['release_date'])
numdf = numdf[numdf['release_date'].dt.year > 2009]

# %% [markdown]
# Values in <code>production_budget</code> and <code>worldwide_gross</code> are strings, we will need to change them to int for analysis.

# %%
numdf['production_budget'] = \
numdf['production_budget'].map(lambda x: int(x.strip('$').replace(',','')))
numdf['worldwide_gross'] = \
numdf['worldwide_gross'].map(lambda x: int(x.strip('$').replace(',','')))

# %%
# Open numbers database and examine first 5 records
tmdf = pd.read_csv('Data/tmdb.movies.csv.gz')
tmdf.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
tmdf.info()  # no missing values found
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
# collecting records with release year of 2010 or later.
tmdf['release_date'] = pd.to_datetime(tmdf['release_date'])
tmdf = tmdf[tmdf['release_date'].dt.year > 2009]

# %% [markdown]
# ## Data Preparation
#
# ### Data Cleaning
#
# For both datasets, I check for any duplicates and drop them if found. Unnecessary columns are dropped and column names are renamed to make working on them easier.

# %%
# Check for any duplicates based on release year and movie name
numdf.value_counts(['release_date', 'movie'])
# Out:
# release_date  movie
# 2020-12-31    Moonfall                   1
# 2012-11-16    Silver Linings Playbook    1
# 2012-11-30    Killing Them Softly        1
# 2012-11-23    De rouille et dâos       1
# 2012-11-21    Rise of the Guardians      1
#                                         ..
# 2015-09-11    90 Minutes in Heaven       1
#               The Perfect Guy            1
#               The Visit                  1
# 2015-09-18    Black Mass                 1
# 2010-01-08    Daybreakers                1
# Length: 2194, dtype: int64

# %%
# Check for any duplicates based on unique id
tmdf['id'].value_counts()
# Out:
# 152044    3
# 378425    3
# 402448    3
# 192767    3
# 192023    3
#          ..
# 350846    1
# 479871    1
# 500353    1
# 439007    1
# 524288    1
# Name: id, Length: 25288, dtype: int64

# %%
tmdf[tmdf['id'] == 152044]
# Out:
#        Unnamed: 0     genre_ids      id original_language  \
# 5532         5532  [53, 16, 14]  152044                ja
# 11484       11484  [53, 16, 14]  152044                ja
# 17896       17896  [53, 16, 14]  152044                ja
#
#                   original_title  popularity release_date  \
# 5532   劇場版 魔法少女まどか☆マギカ[後編] 永遠の物語       6.393   2012-10-19
# 11484  劇場版 魔法少女まどか☆マギカ[後編] 永遠の物語       6.393   2012-10-19
# 17896  劇場版 魔法少女まどか☆マギカ[後編] 永遠の物語       6.393   2012-10-19
#
#                                                    title  vote_average  \
# 5532   Puella Magi Madoka Magica the Movie Part II: E...           8.0
# 11484  Puella Magi Madoka Magica the Movie Part II: E...           8.0
# 17896  Puella Magi Madoka Magica the Movie Part II: E...           8.0
#
#        vote_count
# 5532           53
# 11484          53
# 17896          53

# %%
tmdf[tmdf['id'] == 378425]
# Out:
#        Unnamed: 0 genre_ids      id original_language  \
# 16405       16405      [99]  378425                en
# 19789       19789      [99]  378425                en
# 23048       23048      [99]  378425                en
#
#                  original_title  popularity release_date  \
# 16405  Here Come the Videofreex       0.631   2015-06-21
# 19789  Here Come the Videofreex       0.631   2015-06-21
# 23048  Here Come the Videofreex       0.631   2015-06-21
#
#                           title  vote_average  vote_count
# 16405  Here Come the Videofreex           8.0           1
# 19789  Here Come the Videofreex           8.0           1
# 23048  Here Come the Videofreex           8.0           1

# %%
tmdf[tmdf['id'] == 192767]
# Out:
#        Unnamed: 0 genre_ids      id original_language original_title  \
# 12217       12217      [18]  192767                en          Noble
# 15362       15362      [18]  192767                en          Noble
# 18646       18646      [18]  192767                en          Noble
#
#        popularity release_date  title  vote_average  vote_count
# 12217       1.819   2015-05-08  Noble           6.8          16
# 15362       1.819   2015-05-08  Noble           6.8          16
# 18646       1.819   2015-05-08  Noble           6.8          16

# %% [markdown]
# After examining some of the duplicates found, I concluded that they are the same records and can drop them.

# %%
tmdf = tmdf.drop_duplicates(subset = 'id', keep = 'first')

# %%
tmdf['id'].value_counts()
# Out:
# 71677     1
# 226788    1
# 208091    1
# 67811     1
# 561546    1
#          ..
# 64586     1
# 273488    1
# 97370     1
# 160859    1
# 524288    1
# Name: id, Length: 25288, dtype: int64

# %%
tmdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25288 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         25288 non-null  int64
#  1   genre_ids          25288 non-null  object
#  2   id                 25288 non-null  int64
#  3   original_language  25288 non-null  object
#  4   original_title     25288 non-null  object
#  5   popularity         25288 non-null  float64
#  6   release_date       25288 non-null  datetime64[ns]
#  7   title              25288 non-null  object
#  8   vote_average       25288 non-null  float64
#  9   vote_count         25288 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(4)
# memory usage: 2.1+ MB

# %%
# Drop uneccessary columns
numdf = numdf.drop(columns = ['id', 'domestic_gross'])
tmdf = \
tmdf.drop(columns = ['Unnamed: 0', 'original_language',\
                     'title', 'popularity', 'vote_average', 'vote_count'])

# %%
# Rename movie title column to same name
numdf = numdf.rename(columns = {'movie': 'title'})
tmdf = tmdf.rename(columns = {'original_title': 'title'})

# %% [markdown]
# ### Merging Datasets
#
# We will now merge the 2 datasets together and check for any duplicates.

# %%
# Merge Numbers and TMDB on title and release date
df = numdf.merge(tmdf, on = ['title', 'release_date'])
df.head()
# Out:
#   release_date                                        title  \
# 0   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 1   2015-05-01                      Avengers: Age of Ultron
# 2   2018-04-27                       Avengers: Infinity War
# 3   2017-11-17                               Justice League
# 4   2015-11-06                                      Spectre
#
#    production_budget  worldwide_gross          genre_ids      id
# 0          410600000       1045663875       [12, 28, 14]    1865
# 1          330600000       1403013963      [28, 12, 878]   99861
# 2          300000000       2048134200       [12, 28, 14]  299536
# 3          300000000        655945209  [28, 12, 14, 878]  141052
# 4          300000000        879620923       [28, 12, 80]  206647

# %% [markdown]
# Merged dataset contains 1230 movies ranging from 2010 to 2019

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1230 entries, 0 to 1229
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       1230 non-null   datetime64[ns]
#  1   title              1230 non-null   object
#  2   production_budget  1230 non-null   int64
#  3   worldwide_gross    1230 non-null   int64
#  4   genre_ids          1230 non-null   object
#  5   id                 1230 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 67.3+ KB

# %%
df['release_date'].describe()
# Out:
# <ipython-input-21-1fda778c69b5>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df['release_date'].describe()
# count                    1230
# unique                    525
# top       2015-11-20 00:00:00
# freq                        7
# first     2010-01-08 00:00:00
# last      2019-05-03 00:00:00
# Name: release_date, dtype: object

# %%
# Double check for any duplicates after merge
df['id'].value_counts()
# Out:
# 71679     1
# 119450    1
# 47760     1
# 180296    1
# 86838     1
#          ..
# 276905    1
# 64807     1
# 310569    1
# 286565    1
# 399360    1
# Name: id, Length: 1230, dtype: int64

# %%
df['title'].value_counts()
# Out:
# Robin Hood                      2
# Your Highness                   1
# Concussion                      1
# Birth of the Dragon             1
# Indie Game: The Movie           1
#                                ..
# Eye in the Sky                  1
# Before I Fall                   1
# Black Nativity                  1
# Sin City: A Dame to Kill For    1
# Movie 43                        1
# Name: title, Length: 1229, dtype: int64

# %%
df[df['title'] == 'Robin Hood']
# Out:
#     release_date       title  production_budget  worldwide_gross  \
# 23    2010-05-14  Robin Hood          210000000        322459006
# 181   2018-11-21  Robin Hood           99000000         84747441
#
#         genre_ids      id
# 23   [28, 12, 18]   20662
# 181  [12, 28, 53]  375588

# %% [markdown]
# ## Data Analysis
#
# I focus on three variables (<code>release_date</code>, <code>genre_ids</code>, and <code>production_budget</code>) and find a pattern with respect to <code>worldwide_gross</code>. We will focus on using median as our measure of central tendency to account for any outliers from extremely high performing movies.

# %% [markdown]
# #### Time of release
#
# I create a new column <code>month</code> to group up the release dates by months. Based on the results, movies release during the months of May, June, July, November, and December have a higher worldwide box office gross. These months are concurrent with the summer and holiday seasons.

# %%
# Create new column 'month' that returns the month of each release date
df['month'] = df['release_date'].dt.strftime('%b')

# %% [markdown]
# Based on the number of movies released by month. October had the most followed by September.

# %%
rm = df['month'].value_counts()
rm
# Out:
# Oct    137
# Sep    121
# Aug    112
# Dec    111
# Mar    111
# Nov    105
# Jul    101
# Apr     96
# Jun     96
# Feb     85
# May     84
# Jan     71
# Name: month, dtype: int64

# %%
# sorting months by order
order_list = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul',\
              'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
rm.index = pd.Categorical(rm.index, categories = order_list, ordered = True)

# %%
# Plotting the number of movies released by month to get a visual
sns.set_style('darkgrid')
sns.set(font_scale = 2)
plt.figure(figsize = (10,10))
ax = sns.lineplot(x = rm.index, y = rm, marker = 'o', linewidth = 5, markersize = 20)
ax.set_title('Number of movies released by month')
ax.set(ylabel = 'Number of movies released');

# change label color for presentation
#ax.set_title('Number of movies released by month', color = 'white')
#ax.xaxis.label.set_color('white')
#ax.yaxis.label.set_color('white')
#ax.tick_params(colors = 'white', which = 'both')
#plt.savefig('images/count_movie_month.png', transparent = True)

# save image
#plt.savefig('images/count_movie_month.png')

plt.show()

# %% [markdown]
# From the below graph we can see that movies released in May, June, July, November, and December has the highest worldwide box office results, while having less movies released than October and September.

# %%
# sorting months by order
order_list = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul',\
              'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df['month'] = pd.Categorical(df['month'], categories = order_list, ordered = True)

# %%
# Using seaborn boxplot to show distribution of 
# worldwide gross of movies released by months
sns.set_style('darkgrid')
sns.set(font_scale = 2)
plt.figure(figsize = (20,20))
ax = sns.lineplot(x = 'month', y = 'worldwide_gross', estimator = np.median, \
                 data = df, ci = None, marker = 'o', linewidth = 5, markersize = 20)
# edit for presentation purpose
#ax = sns.lineplot(x = 'month', y = 'worldwide_gross', estimator = np.median, \
#                 data = df, ci = None, marker = 'o', linewidth = 5, markersize = 20, color = '#f7e7c6')
ax.set_title('Worldwide Box Office by Month of release')
ax.set(xlabel = 'Release Months', ylabel = 'Worldwide Gross Box Office USD')
ax.yaxis.set_major_formatter\
(ticker.FuncFormatter(lambda x, pos: '{:,.2f}'.format(x/1000000) + 'M'))

# change transparency and label/tick colors for presentation
#ax.set_title('Worldwide Box Office by Month of release', color = 'white')
#ax.xaxis.label.set_color('white')
#ax.yaxis.label.set_color('white')
#ax.tick_params(colors = 'white', which = 'both')
#plt.savefig('images/movie_month_gross.png', transparent = True)

# save image
#plt.savefig('images/movie_month_gross.png')
plt.show()

# %% [markdown]
# #### Genres
#
# Movies with the animation sub-genre associated to them have highest average worldwide box office gross. Followed by adventure and fantasy.

# %%
# Seperate sub genres in movies and count them as a movie in each genre.
# Change genre id from a list within a string to a list of strings
df['genre_ids'] = df['genre_ids'].str.strip('[]').str.split(', ') 
genre_data = df.explode('genre_ids')

# %%
# Check if values seperated correctly
genre_data['genre_ids'].value_counts()
# Out:
# 18       571
# 35       419
# 53       354
# 28       341
# 12       234
# 80       177
# 878      158
# 10749    157
# 27       154
# 10751    144
# 14       138
# 9648      93
# 16        83
# 36        47
# 10402     38
# 10752     32
# 37        17
# 99        13
#            1
# Name: genre_ids, dtype: int64

# %%
# check blank genre
genre_data[genre_data['genre_ids'] == '']
# Out:
#      release_date              title  production_budget  worldwide_gross  \
# 1211   2015-10-23  The Looking Glass             300000             1711
#
#      genre_ids      id month
# 1211            365052   Oct

# %%
# since it is only one record we can manually input the genre, it was found to be a Drama
genre_data.loc[genre_data['genre_ids'] == '', 'genre_ids'] = '18'

# %%
genre_data['genre_ids'].value_counts()
# Out:
# 18       572
# 35       419
# 53       354
# 28       341
# 12       234
# 80       177
# 878      158
# 10749    157
# 27       154
# 10751    144
# 14       138
# 9648      93
# 16        83
# 36        47
# 10402     38
# 10752     32
# 37        17
# 99        13
# Name: genre_ids, dtype: int64

# %%
# create a list to change genre ids into their respective names
# genre list found in TMDB API documentation
genre_list = {'28': 'Action', '12': 'Adventure', '16': 'Animation',\
              '35': 'Comedy', '80': 'Crime', '99': 'Documentary',\
              '18': 'Drama', '10751': 'Family', '14': 'Fantasy', \
              '36': 'History', '27': 'Horror', '10402': 'Music',\
              '9648': 'Mystery', '10749': 'Romance', '878': 'Sci-Fi',\
              '10770': 'TV Movie', '53': 'Thriller', '10752': 'War',\
              '37': 'Western'}
# Chang ids into respective names by passing through the map function
genre_data['genre_ids'] = genre_data['genre_ids'].map(genre_list)

# %% [markdown]
# Below results shows the highest number of movies released during this period is associated with the Drama genre followed by Comedy.

# %%
gd = genre_data['genre_ids'].value_counts()
gd
# Out:
# Drama          572
# Comedy         419
# Thriller       354
# Action         341
# Adventure      234
# Crime          177
# Sci-Fi         158
# Romance        157
# Horror         154
# Family         144
# Fantasy        138
# Mystery         93
# Animation       83
# History         47
# Music           38
# War             32
# Western         17
# Documentary     13
# Name: genre_ids, dtype: int64

# %%
# Plotting the count of movies using.
sns.set_style('darkgrid')
sns.set(font_scale = 1)
plt.figure(figsize = (20,20))
ax = sns.barplot(x = gd.index, y = gd, data = genre_data)
plt.xticks(rotation = 45, fontsize = 20)
ax.set_title('Number of movies released by genre', fontsize = 40)
ax.set_ylabel('Number of movies released', fontsize = 30)
ax.set_xlabel('Genres', fontsize = 30)

# change transparency and label/tick colors for presentation
#ax.set_title('Number of movies released by genre', color = 'white', \
#             fontsize = 40)
#ax.xaxis.label.set_color('white')
#ax.yaxis.label.set_color('white')
#ax.tick_params(colors = 'white', which = 'both')
#plt.savefig('images/count_genre.png', transparent = True)

# save image
#plt.savefig('images/count_genre.png')
plt.show()

# %%
# Group movies by their genre while averaging the worldwide_gross
grouped_genre = genre_data.groupby('genre_ids')['worldwide_gross'].median()

# %%
# Sort by worldwide_gross by decsending value
grouped_genre = grouped_genre.sort_values(ascending = False)

# %% [markdown]
# Animation has the highest average worldwide box office results, while having less movies released than Drama.

# %%
# Plot results
sns.set_style('darkgrid')
sns.set(font_scale = 2)
plt.figure(figsize = (20,20))
ax = sns.barplot(x = 'genre_ids', y = 'worldwide_gross' , data = genre_data,\
                 order = grouped_genre.index, estimator = np.median, ci = None)
plt.xticks(rotation = 45, fontsize = 20)
ax.set_title('Average Worldwide Box Office by Genres')
ax.set_xlabel('Genres')
ax.set_ylabel('Worldwide Gross Box Office USD')
ax.yaxis.set_major_formatter\
(ticker.FuncFormatter(lambda x, pos: '{:,.2f}'.format(x/1000000) + 'M'))

# change transparency and label/tick colors for presentation
#ax.set_title('Average Worldwide Box Office by Genres', color = 'white',\
#             fontsize = 40)
#ax.xaxis.label.set_color('white')
#ax.yaxis.label.set_color('white')
#ax.tick_params(colors = 'white', which = 'both')
#plt.savefig('images/genre_gross.png', transparent = True)

# save image
#plt.savefig('images/genre_gross.png')
plt.show()

# %% [markdown]
# #### Production Budget
#
# A positive correaltion is found between <code>production_budget</code> and <code>worldwide_gross</code>. This shows that higher production budgets tend to result in higher worldwide box office gross.

# %%
# Create Plot
sns.set_style('darkgrid')
sns.set(font_scale = 2)
plt.figure(figsize = (20,20))
ax = sns.regplot(x = 'production_budget', y = 'worldwide_gross', data = df)

# edit for presentation purpose
#ax = sns.regplot(x = 'production_budget', y = 'worldwide_gross', data = df,\
#                 scatter_kws = {'color': '#cda04b'}, \
#                 line_kws = { 'color': '#f7e7c6'})

ax.set_title('Production Budget vs Worldwide gross Box office')
ax.set_xlabel('Production Budget USD') 
ax.set_ylabel('Worldwide Gross Box Office USD')
ax.xaxis.set_major_formatter\
(ticker.FuncFormatter(lambda x, pos: '{:,.2f}'.format(x/1000000) + 'M'))
ax.yaxis.set_major_formatter\
(ticker.FuncFormatter(lambda x, pos: '{:,.2f}'.format(x/1000000000) + 'B'))

# change transparency and label/tick colors for presentation
#ax.set_title('Production Budget vs Worldwide gross Box office', \
#            color = 'white')
#ax.xaxis.label.set_color('white')
#ax.yaxis.label.set_color('white')
#ax.tick_params(colors = 'white', which = 'both')
#plt.savefig('images/budget_vs_gross.png', transparent = True)

# save image
#plt.savefig('images/budget_vs_gross.png')
plt.show()

# %% [markdown]
# We want to see if production budget has any effects on the chance of a movie's success. Based on whether a movie's box office results made back its production budget, we will create a new column <code>profit</code> that calculates the difference between worldwide gross and production budget.

# %%
df['profit'] = df['worldwide_gross'] - df['production_budget']

# %% [markdown]
# Based on the value in <code>profit</code>, we will create another column to identify if a movie's success. We will assume a movie has succeed if it has made back it's production budget in worldwide box office gross with Success as breaking even or more and Loss as not making enough to cover the production budget.

# %%
df['budget_return'] = df['profit'].map(lambda x: 'Success' \
                                       if x >= 0 else 'Loss' )

# %% [markdown]
# Results show that as production budget increases, the chance of a movie's success increases.

# %%
# Create Plot
sns.set_style('darkgrid')
sns.set(font_scale = 2)
plt.figure(figsize = (20,20))
ax = sns.scatterplot(x = 'production_budget', y = 'worldwide_gross', \
                     data = df, hue = 'budget_return')
ax.set_title('Production Budget vs Worldwide gross Box office')
ax.set_xlabel('Production Budget USD')
ax.set_ylabel('Worldwide Gross Box Office USD')
ax.xaxis.set_major_formatter\
(ticker.FuncFormatter(lambda x, pos: '{:,.2f}'.format(x/1000000) + 'M'))
ax.yaxis.set_major_formatter\
(ticker.FuncFormatter(lambda x, pos: '{:,.2f}'.format(x/1000000000) + 'B'))

# save image
#plt.savefig('images/budget_return_gross.png')
plt.show()

# %% [markdown]
# We will split production budget into different budget categories and calculate the chance of success from each category.

# %%
# Create bins to split production budget into
bins = [0, 5000000, 10000000, 25000000, 50000000, 75000000,\
        100000000, 150000000, 200000000, np.inf]
bin_list = ['Less than 5M', '5M - 10M', '10M - 25M', '25M - 50M',\
            '50M - 75M', '75M - 100M', '100M - 150M', '150M - 200M',\
            'Over 200M']
# Create a new column to identify which budget category the movie belongs to
df['budget_category'] = pd.cut(df['production_budget'], bins = bins,\
                               labels = bin_list)
df.head()
# Out:
#   release_date                                        title  \
# 0   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 1   2015-05-01                      Avengers: Age of Ultron
# 2   2018-04-27                       Avengers: Infinity War
# 3   2017-11-17                               Justice League
# 4   2015-11-06                                      Spectre
#
#    production_budget  worldwide_gross          genre_ids      id month  \
# 0          410600000       1045663875       [12, 28, 14]    1865   May
# 1          330600000       1403013963      [28, 12, 878]   99861   May
# 2          300000000       2048134200       [12, 28, 14]  299536   Apr
# 3          300000000        655945209  [28, 12, 14, 878]  141052   Nov
# 4          300000000        879620923       [28, 12, 80]  206647   Nov
#
#        profit budget_return budget_category
# 0   635063875       Success       Over 200M
# 1  1072413963       Success       Over 200M
# ...

# %% [markdown]
# To find the chance of success, we group up the movies based on buget category and count the values. We then normalize the values to find the percent of success and loss.

# %%
rate = df.groupby('budget_category')['budget_return'].value_counts(normalize = True)
rate
# Out:
# budget_category  budget_return
# Less than 5M     Success          0.522088
#                  Loss             0.477912
# 5M - 10M         Success          0.632000
#                  Loss             0.368000
# 10M - 25M        Success          0.698885
#                  Loss             0.301115
# 25M - 50M        Success          0.784314
#                  Loss             0.215686
# 50M - 75M        Success          0.840000
#                  Loss             0.160000
# 75M - 100M       Success          0.890625
#                  Loss             0.109375
# 100M - 150M      Success          0.936709
#                  Loss             0.063291
# 150M - 200M      Success          0.953846
#                  Loss             0.046154
# Over 200M        Success          1.000000
# Name: budget_return, dtype: float64

# %% [markdown]
# Using unstack function, we pivot the dataframe to show Success and Loss columns for each budget category.

# %%
ratedf = rate.unstack('budget_return')
ratedf
# Out:
# budget_return        Loss   Success
# budget_category
# Less than 5M     0.477912  0.522088
# 5M - 10M         0.368000  0.632000
# 10M - 25M        0.301115  0.698885
# 25M - 50M        0.215686  0.784314
# 50M - 75M        0.160000  0.840000
# 75M - 100M       0.109375  0.890625
# 100M - 150M      0.063291  0.936709
# 150M - 200M      0.046154  0.953846
# Over 200M             NaN  1.000000

# %%
# Plot a stacked bar graph of Success and Loss in budget return based on budget category
plt.style.use('ggplot')
colors = {'Loss': '#cb4c4e', 'Success': '#83a1cd'}
ax = ratedf.plot.barh(figsize = (15,10), stacked = True, color = colors);
for rect in ax.patches:
    # find where each bar is located
    height = rect.get_height()
    width = rect.get_width()
    x = rect.get_x()
    y = rect.get_y()
    
    # The height of the bar is the data value and can be used as the label
    label_text = f'{(width*100):.1f}%'  # format text to show only 1 decimal place in percentage
    
    # ax.text(x, y, text)
    label_x = x + width / 2
    label_y = y + height / 2
    
    # only plot labels greater than given width
    if width > 0:
        ax.text(label_x, label_y, label_text, ha='center', va='center',\
                fontsize=15)

# move the legend
ax.legend(bbox_to_anchor=(1, 1), loc='upper left')
ax.xaxis.set_ticklabels([])
ax.set_ylabel('Production Budget Range', fontsize = 25)
ax.set_title('Chance of Success by Production Budget', fontsize = 30)

# change transparency and label/tick colors for presentation
#ax.set_title('Chance of Success by Production Budget', color = 'white')
#ax.yaxis.label.set_color('white')
#ax.tick_params(colors = 'white', which = 'both')
#ax.legend(bbox_to_anchor=(1, 1), loc='upper left', framealpha = 0, labelcolor = 'white')
#plt.savefig('images/success_chance.png', bbox_inches = 'tight', transparent = True)

# save image
#plt.savefig('images/success_chance.png', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# Now that we have an idea of how a movie's production budget will affect it's chance of success, we look at the average production budget for the top 3 genres.

# %%
adv = genre_data['genre_ids'] == 'Adventure'
ani = genre_data['genre_ids'] == 'Animation'
fan = genre_data['genre_ids'] == 'Fantasy'
top_genre = genre_data[adv | ani | fan]

# %%
top_genre.groupby('genre_ids')['production_budget'].median()
# Out:
# genre_ids
# Adventure    109000000
# Animation     80000000
# Fantasy       90500000
# Name: production_budget, dtype: int64

# %% [markdown]
# Animation has a lower average production budget, but it still had a higher average box office revenue.

# %%
sns.set_style('darkgrid')
sns.set(font_scale = 2)
plt.figure(figsize = (5,15))
ax = sns.barplot(x = 'genre_ids', y = 'production_budget', data = top_genre,\
                 estimator = np.median, ci = None)
ax.yaxis.set_major_formatter\
(ticker.FuncFormatter(lambda x, pos: '{:,.2f}'.format(x/1000000) + 'M'))
ax.set_title('Top Genres Average Production Budget')
ax.set_ylabel('Production Budget USD')
ax.set_xlabel('Genres')

# change transparency and label/tick colors for presentation
#ax.set_title('Top Genres Average Production Budget', color = 'white')
#ax.xaxis.label.set_color('white')
#ax.yaxis.label.set_color('white')
#ax.tick_params(colors = 'white', which = 'both')
#plt.savefig('images/top_budget.png', transparent = True, bbox_inches = 'tight')

# save image
#plt.savefig('images/top_budget.png', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# We will now check to see when is it the best time to release an animation movie.

# %%
top_genre['month'] = top_genre['release_date'].dt.strftime('%b')
# Out:
# <ipython-input-53-3a5af2a94d9b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_genre['month'] = top_genre['release_date'].dt.strftime('%b')

# %%
# sorting months by order
order_list = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul',\
              'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
genre_data['month'] = pd.Categorical(genre_data['month'], categories = order_list, ordered = True)

# %%
sns.set_style('darkgrid')
sns.set(font_scale = 2)
plt.figure(figsize = (20,20))
ax = sns.lineplot(x = 'month', y = 'worldwide_gross',estimator = np.median, \
                 data = genre_data[ani], ci = None, marker = 'o', linewidth = 5, markersize = 20)
# edit for presentation purpose
#ax = sns.lineplot(x = 'month', y = 'worldwide_gross',estimator = np.median, \
#                 data = genre_data[ani], ci = None, marker = 'o', linewidth = 5, markersize = 20, color = '#f7e7c6')
ax.set_title('Average Animation Worldwide Box Office by Month of Release')
ax.set_ylabel('Worldwide Gross Box Office USD')
ax.set_xlabel('Release Months')
ax.yaxis.set_major_formatter\
(ticker.FuncFormatter(lambda x, pos: '{:,.2f}'.format(x/1000000) + 'M'))

# change transparency and label/tick colors for presentation
#ax.set_title('Average Animation Worldwide Box Office by Month of Release', color = 'white')
#ax.xaxis.label.set_color('white')
#ax.yaxis.label.set_color('white')
#ax.tick_params(colors = 'white', which = 'both')
#plt.savefig('images/genre_month_gross.png', transparent = True)

# save image
#plt.savefig('images/genre_month_gross.png')
plt.show()

# %% [markdown]
# ## Conclusions
#
# This analysis leads to three recommendations to help Microsoft in deciding what movie to make:
#
# - __Type of movie.__ While there are alot of different genres and sub genres in movies now. Movies with higher box office totals have shown to be of the animation genre.
#
# - __Time of release.__ The months of June, July have shown to have brought back higher box office revenue for Animation movies.
#
# - __Price of success.__ Analysis shows spending a minimum of 80 million dollars will give a high chance of bring back a positive return on investment.
#
# There are many variables to examine to predict box office success of a movie. This analysis only looked at three of them.
#
# ## Next Steps
#
# Further data and analysis can help Microsoft narrow down their decision making.
#
# - __Marketing plays a big part in movie sucess.__  Examing this data could give insights on how audiences respond to different marketing techniques when promoting a movie.
# - __Other markets.__ In this analysis we only looked at worldwide box office gross as the deciding factor to success. With the growth of streaming services, we can look at these other forms of revenue to help with decision making.
